# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
df = pd.read_csv("Netflix_Engagement_Report_2023_Jan-Jun_cleaned.csv", index_col=0)
df.head(15)
# Out:
#                                           Available Globally Release Date  \
# Title
# The Night Agent: Season 1                                Yes    3/23/2023
# Ginny & Georgia: Season 2                                Yes     1/5/2023
# The Glory: Season 1 // 더 글로리: 시즌 1                       Yes   12/30/2022
# Wednesday: Season 1                                      Yes   11/23/2022
# Queen Charlotte: A Bridgerton Story                      Yes     5/4/2023
# You: Season 4                                            Yes     2/9/2023
# La Reina del Sur: Season 3                                No   12/30/2022
# Outer Banks: Season 3                                    Yes    2/23/2023
# Ginny & Georgia: Season 1                                Yes    2/24/2021
# FUBAR: Season 1                                          Yes    5/25/2023
# Manifest: Season 4                                       Yes    11/4/2022
# Kaleidoscope: Limited Series                             Yes     1/1/2023
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18214 entries, The Night Agent: Season 1 to 선생 김봉두
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Available Globally  18214 non-null  object
#  1   Release Date        4855 non-null   object
#  2   Hours Viewed        18214 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 569.2+ KB

# %%
df.describe()
# Out:
#        Hours Viewed
# count  1.821400e+04
# mean   5.130954e+06
# std    1.871767e+07
# min    1.000000e+05
# 25%    2.000000e+05
# 50%    7.000000e+05
# 75%    3.400000e+06
# max    8.121000e+08

# %%
duplicados = df[df.duplicated(keep='first')]
print(duplicados)
# Out:
#                                    Available Globally Release Date  \
# Title
# Peppa Pig: Season 2                                No          NaN
# New Amsterdam (2018): Season 4                     No          NaN
# The Walking Dead: Season 9                         No          NaN
# Rosario Tijeras (Mexico): Season 1                 No          NaN
# Teen Titans Go!: Season 5                          No          NaN
# ...                                               ...          ...
# راس السنة                                          No          NaN
# 心が叫びたがってるんだ。                                       No          NaN
# 두근두근 내 인생                                          No          NaN
# 라디오 스타                                             No          NaN
# 선생 김봉두                                             No          NaN
#
#                                     Hours Viewed
# Title
# Peppa Pig: Season 2                     63700000
# ...

# %%
df.drop_duplicates(keep='first', inplace=True)

# %%
df.head(30)
# Out:
#                                                    Available Globally  \
# Title
# The Night Agent: Season 1                                         Yes
# Ginny & Georgia: Season 2                                         Yes
# The Glory: Season 1 // 더 글로리: 시즌 1                                Yes
# Wednesday: Season 1                                               Yes
# Queen Charlotte: A Bridgerton Story                               Yes
# You: Season 4                                                     Yes
# La Reina del Sur: Season 3                                         No
# Outer Banks: Season 3                                             Yes
# Ginny & Georgia: Season 1                                         Yes
# FUBAR: Season 1                                                   Yes
# Manifest: Season 4                                                Yes
# Kaleidoscope: Limited Series                                      Yes
# ...

# %%
df.dropna(inplace=True) # excluir as linhas com dados faltantes

# %%
date = df[df['Release Date'].str.contains('4/11/2023')] # filtrando registro
print(date)
# Out:
#                                Available Globally Release Date  Hours Viewed
# Title
# Leanne Morgan: I'm Every Woman                 No    4/11/2023       6700000
